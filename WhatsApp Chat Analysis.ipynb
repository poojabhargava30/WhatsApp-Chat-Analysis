# %%
import regex
import pandas as pd
import numpy as np
import emoji
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
def date_time(s):
    pattern = '^([0-9]+)(\/)([0-9]+)(\/)([0-9]+), ([0-9]+):([0-9]+)[ ]?(AM|PM|am|pm)? -'
    result = regex.match(pattern, s)
    if result:
        return True
    return False

def find_author(s):
    s=s.split(":")
    if len(s)==2:
        return True
    else:
        return False

def getDatapoint(line):
    splitline = line.split(' - ')
    dateTime = splitline[0]
    date, time = dateTime.split(", ")
    message = " ".join(splitline[1:])
    if find_author(message):
        splitmessage = message.split(": ")
        author = splitmessage[0]
        message = " ".join(splitmessage[1:])
    else:
        author= None
    return date, time, author, message

# %%
data = []
conversation = 'WhatsApp Chat with BIT Compiler Design Group.txt'
with open(conversation, encoding="utf-8") as fp:
    fp.readline()
    messageBuffer = []
    date, time, author = None, None, None
    while True:
        line = fp.readline()
        if not line:
            break
        line = line.strip()
        if date_time(line):
            if len(messageBuffer) > 0:
                data.append([date, time, author, ' '.join(messageBuffer)])
            messageBuffer.clear()
            date, time, author, message = getDatapoint(line)
            messageBuffer.append(message)
        else:
            messageBuffer.append(line)

# %%
df = pd.DataFrame(data, columns=["Date", 'Time', 'Author', 'Message'])
df['Date'] = pd.to_datetime(df['Date'])
print(df.tail(20))
print(df.info())
print(df.Author.unique())
# Out:
#           Date     Time            Author  \
# 468 2021-01-04  1:57 pm            Priyam
# 469 2021-12-04  8:23 pm     Padmavati Mam
# 470 2021-12-04  8:23 pm     Padmavati Mam
# 471 2021-12-04  8:23 pm     Padmavati Mam
# 472 2021-12-04  8:24 pm     Padmavati Mam
# 473 2021-12-04  8:24 pm     Padmavati Mam
# 474 2021-12-04  8:24 pm     Padmavati Mam
# 475 2021-12-04  8:24 pm     Padmavati Mam
# 476 2021-12-04  8:38 pm     Padmavati Mam
# 477 2021-12-04  8:48 pm     Padmavati Mam
# 478 2021-12-04  8:48 pm     Padmavati Mam
# 479 2021-12-04  8:50 pm              None
# 480 2021-12-04  8:53 pm  +91 6263 510 163
# 481 2021-12-04  8:57 pm   +91 82340 68546
# 482 2021-12-04  8:57 pm   +91 91742 49950
# 483 2021-12-04  8:58 pm             Suman
# 484 2021-12-04  8:58 pm           Vikrant
# 485 2021-12-04  8:59 pm          Himanshu
# 486 2021-12-04  8:59 pm     Padmavati Mam
# 487 2021-12-04  9:01 pm    Ayush Upadhyay
#
#                                                Message
# 468                                  Get well soon mam
# 469                                    <Media omitted>
# 470                                       Unit 4 notes
# 471         I had covered 80 percent before I fell ill
# 472                 Will be sending short videos by me
# 473                       I'm sure you will understand
# 474  And after 4-5 videos I'll take a class for dou...
# 475  We can proceed this way till doctor gives me g...
# 476                                    <Media omitted>
# 477                                     Kindly respond
# 478    If my inputs not needed I won't strain myself 🙏
# 479  Padmavati Mam: L-value: “l-value” refers to me...
# 480     Thank you so much ma'am 😊. And Get well soon !
# 481                           Thank You So Much Ma'am!
# 482                                      Thank you mam
# 483                             Thank you so much mam😊
# 484        Thankyou so much ma'am. Get well soon maam!
# 485                           thank you so much ma'am!
# 486  Jaldi wapas ayegi Rani Padmavati   Picture phi...
# 487                           Thank you so much ma'am!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     488 non-null    datetime64[ns]
#  1   Time     488 non-null    object
#  2   Author   421 non-null    object
#  3   Message  488 non-null    object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 15.4+ KB
# None
# [None 'Himanshu' 'Priya' 'Pooja Bhargava' 'Padmavati Mam'
#  '+91 79995 08994' 'Ayush Upadhyay' 'Suman' 'Lesica' 'Abhilasha' 'Sawraj'
#  'Ranjana' '+91 70245 83491' '+91 83496 20576' 'Sunidhi' 'Ruchika'
#  'Lawleen' '+91 83196 37190' 'Saket Verma' '+91 78698 51371'
#  '+91 79998 18455' '+91 90983 27421' 'Vipasha' 'Abhishek'
#  '+91 98931 34232' 'Shubhangi' '+91 82340 68546' '+91 97549 24012'
#  '+91 99937 44911' '+91 96856 65536' 'Mansi Gupta' '+91 6263 510 163'
#  '+91 88785 98864' '+91 77720 11609' 'Shivanshi' 'Mahima'
#  '+91 94077 74825' '+91 70890 99220' '+91 74406 88228' 'Vikrant'
#  '+91 72230 77108' '+91 70245 82900' '+91 91742 49950' 'Priyam']
